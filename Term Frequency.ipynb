# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import time
import operator
from collections import Counter

# %%
df_small = pd.read_csv('../data/small_sample.csv')
df = pd.read_csv('../data/large_sample.csv')
df_small.drop(columns=['Unnamed: 0'], inplace=True)
df.drop(columns=['Unnamed: 0'], inplace=True)
df.rating = np.ceil(df.rating)
df_small.rating = np.ceil(df_small.rating)

# %%
def create_count(comment):
    for x in comment.split(' '):
        if x in di:
            di[x.lower()] += 1
        else:
            di[x.lower()] = 1
    return di

# %%
# %%time
di = dict()
df.loc[df.rating == 1].loc[df.comment.apply(lambda x: len(x.split(' ')))<30].comment.apply(create_count)
one_dict = di
di = dict()
df.loc[df.rating == 2].loc[df.comment.apply(lambda x: len(x.split(' ')))<30].comment.apply(create_count)
two_dict = di
di = dict()
df.loc[df.rating == 3].loc[df.comment.apply(lambda x: len(x.split(' ')))<30].comment.apply(create_count)
three_dict = di
di = dict()
df.loc[df.rating == 4].loc[df.comment.apply(lambda x: len(x.split(' ')))<30].comment.apply(create_count)
four_dict = di
di = dict()
df.loc[df.rating == 5].loc[df.comment.apply(lambda x: len(x.split(' ')))<30].comment.apply(create_count)
five_dict = di
di = dict()
df.loc[df.rating == 6].loc[df.comment.apply(lambda x: len(x.split(' ')))<30].comment.apply(create_count)
six_dict = di
di = dict()
df.loc[df.rating == 7].loc[df.comment.apply(lambda x: len(x.split(' ')))<30].comment.apply(create_count)
seven_dict = di
di = dict()
df.loc[df.rating == 8].loc[df.comment.apply(lambda x: len(x.split(' ')))<30].comment.apply(create_count)
eight_dict = di
di = dict()
df.loc[df.rating == 9].loc[df.comment.apply(lambda x: len(x.split(' ')))<30].comment.apply(create_count)
nine_dict = di
di = dict()
df.loc[df.rating == 10].loc[df.comment.apply(lambda x: len(x.split(' ')))<30].comment.apply(create_count)
ten_dict = di
# Out:
# CPU times: user 40.6 s, sys: 800 ms, total: 41.4 s
# Wall time: 43.2 s

# %%
# %%time
one_counter = Counter(one_dict)
two_counter = Counter(two_dict)
three_counter = Counter(three_dict)
four_counter = Counter(four_dict)
five_counter = Counter(five_dict)
six_counter = Counter(six_dict)
seven_counter = Counter(seven_dict)
eight_counter = Counter(eight_dict)
nine_counter = Counter(nine_dict)
ten_counter = Counter(ten_dict)
# Out:
# CPU times: user 35.1 ms, sys: 4.83 ms, total: 39.9 ms
# Wall time: 47.1 ms

# %%
all_counter = one_counter + two_counter + three_counter + four_counter + five_counter + six_counter + seven_counter + eight_counter + nine_counter + ten_counter

# %%
all_dict = dict(Counter(all_counter))

# %%
all_dict
# Out:
# {'i': 11,
#  'hate': 157,
#  'this': 64,
#  'game': 261,
#  'worse': 89,
#  'than': 6287,
#  'any': 147,
#  'that': 369,
#  'have': 180,
#  'ever': 499,
#  'played.': 812,
#  'it': 44,
#  'poisen!': 1,
#  'its': 72,
#  'tedious,': 39,
#  "it's": 16,
#  'too': 83,
#  'long,': 63,
#  'in': 284,
#  'short': 51,
#  'sucks!': 10,
#  'boring': 172,
#  'another': 24,
#  'piece': 168,
#  'of': 2751,
#  'trash': 66,
#  'from': 503,
#  'bezier.': 1,
#  '': 179603,
#  'unfortunate': 19,
#  'a': 43,
#  'appeals': 38,
#  'to': 1023,
#  'the': 71,
#  'absolute': 44,
#  'lowest': 57,
#  'common': 73,
#  'denominator': 6,
#  'could': 91,
#  'do': 112,
#  'so': 75,
#  'well.': 1790,
#  'rather': 163,
#  'die': 72,
#  'by': 409,
#  'papercuts': 1,
#  'play': 299,
#  'again.': 3113,
#  'played': 42,
#  'once.': 301,
#  'there': 35,
#  'are': 2449,
#  'great': 35,
#  'wwii': 9,
#  'grand': 19,
#  'strategic': 113,
#  'games.': 768,
#  "there's": 15,
#  'also': 22,
#  '"risk".': 4,
#  'is': 731,
#  'neither.': 12,
#  'never': 55,
#  'detested': 2,
#  'element': 713,
#  'chance': 360,
#  'much.': 866,
#  'deadly': 16,
#  'dull.': 111,
#  'every': 90,
#  'was': 173,
#  'same.': 302,
#  'makes': 50,
#  'risk': 18,
#  'look': 141,
#  'fun.': 440,
#  'painful': 57,
#  'just': 47,
#  'set': 72,
#  'up.': 704,
#  'smjj': 57,
#  'loves': 282,
#  'game,': 932,
#  'must': 41,
#  ':p': 24,
#  '[b]owner:[/b]': 4,
#  'irrelevant': 28,
#  '[b]recommended': 7,
#  'players:[/b]': 33,
#  '4': 6590,
#  '[b]interest': 3,
#  'level:[/b]': 32,
#  'none': 33,
#  '[b]trade': 1,
#  'note:[/b]': 8,
#  'use': 101,
#  'category': 37,
#  'denote': 9,
#  'games': 104,
#  '"i': 10,
#  "don't": 111,
#  'want': 279,
#  'play".': 20,
#  '[b]dislikes:[/b]': 1,
#  '-': 17661,
#  'card-drafting': 52,
#  'ok,': 14,
#  "we're": 45,
#  'finally': 31,
#  'finished': 67,
#  'teeeedious': 1,
#  'card': 62,
#  'drafting': 77,
#  'process.': 50,
#  'now': 36,
#  'we': 28,
#  'can': 65,
#  'start': 184,
#  'right?...what!?': 1,
#  'whole': 324,
#  'game??!?!': 1,
#  "you've": 125,
#  'got': 35,
#  'be': 1051,
#  'kidding': 12,
#  'me...': 174,
#  'rating': 21,
#  'thanks': 24,
#  'smjj.': 32,
#  'sucks': 48,
#  'and': 341,
#  'boring!': 29,
#  'therefore': 98,
#  'one': 44,
#  'most': 113,
#  "i've": 11,
#  'had': 97,
#  'misfortune': 5,
#  'playing.': 1125,
#  'plays:': 11,
#  '25+?': 1,
#  'before': 226,
#  'knew': 180,
#  'what': 66,
#  'good': 43,
#  'board': 204,
#  'were.': 15,
#  'gave': 25,
#  'up': 331,
#  'after': 61,
#  '3': 5426,
#  'hours': 138,
#  'stuck': 106,
#  'on': 436,
#  'outer-most': 1,
#  'track.': 126,
#  'responsible': 27,
#  'for': 237,
#  'my': 51,
#  'irrational': 8,
#  'dislike': 184,
#  'with': 697,
#  'fantasy-themed': 14,
#  'box': 36,
#  'art.': 272,
#  'completely': 58,
#  'broken': 47,
#  'unplayable.': 26,
#  "couldn't": 47,
#  'even': 97,
#  'enjoy': 323,
#  'totally': 39,
#  'random': 94,
#  'clusterfuck': 2,
#  'while': 60,
#  'drunk.': 50,
#  'feels': 34,
#  'like': 154,
#  'monopoly': 11,
#  'fantasy': 22,
#  'veneer.': 8,
#  'worst': 65,
#  'ever.': 81,
#  'entices': 2,
#  'you': 85,
#  'think': 413,
#  'might': 38,
#  'awesome,': 28,
#  'but': 108,
#  'dumb': 52,
#  'little': 485,
#  'kids.': 791,
#  'no': 44,
#  'strategy.': 1182,
#  '*technically': 1,
#  'unplayed': 19,
#  'relic': 13,
#  'other': 508,
#  'day,': 44,
#  'kinda': 43,
#  'sucked.': 12,
#  "i'm": 10,
#  'extrapolating': 1,
#  'similar': 65,
#  'expectations': 67,
#  'here.': 1149,
#  'may': 47,
#  'experience': 274,
#  'life': 114,
#  'ive': 15,
#  'been': 149,
#  'hit': 352,
#  'car': 41,
#  'talisman': 10,
#  'munchkin': 14,
#  'board.': 387,
#  '(smae': 1,
#  'basic': 77,
#  'problems)': 1,
#  'except': 110,
#  'require': 220,
#  'more': 159,
#  'dependance': 10,
#  'luck...': 38,
#  'bad': 157,
#  'components,': 455,
#  'gameplay,': 381,
#  'depth': 279,
#  'whatsoever,': 8,
#  'entirely': 78,
#  'way': 67,
#  'damn': 36,
#  'random,': 54,
#  'quality': 71,
#  'control,': 56,
#  'literal': 11,
#  'everything.': 108,
#  'least': 467,
#  'fun': 47,
#  'game.': 1788,
#  'figurine-play': 1,
#  'adolecents.': 2,
#  'throw': 57,
#  'see': 80,
#  'who': 57,
#  'wins,': 50,
#  'only': 44,
#  'drawn': 110,
#  'out': 601,
#  'over': 251,
#  '2-5': 934,
#  'hours.': 307,
#  'roll': 18,
#  'move': 157,
#  'very': 28,
#  'minute': 221,
#  'amount': 486,
#  'strategy': 119,
#  'involved': 402,
#  'play.': 1499,
#  'not': 30,
#  'really': 62,
#  'fun,': 48,
#  'takes': 46,
#  'forever': 140,
#  'boot.': 106,
#  'overhyped': 27,
#  'amateur': 14,
#  'unknown': 24,
#  'designer': 44,
#  'should': 85,
#  'learn': 348,
#  'design': 141,
#  'sid': 9,
#  "meier's": 9,
#  'civilization': 26,
#  '(both': 23,
#  'computer': 145,
#  'boardgame': 67,
#  'ffg)': 2,
#  'wars': 11,
#  'ruined': 131,
#  'me.': 5597,
#  'where': 279,
#  'get': 376,
#  'an': 39,
#  'advantage': 208,
#  'attacking': 46,
#  'player': 193,
#  'last': 54,
#  'scope': 74,
#  'though': 122,
#  'am': 188,
#  'finding': 20,
#  'difficult': 59,
#  'learn.': 1223,
#  'lots': 36,
#  'going': 241,
#  'long': 164,
#  'boring.': 226,
#  'wish': 47,
#  'those': 147,
#  'back': 282,
#  'life.': 117,
#  'oren': 1,
#  'recommaded': 1,
#  'civ': 23,
#  'building': 87,
#  'nothing': 24,
#  'special,': 81,
#  'tech': 32,
#  'tree': 33,
#  'innovative': 44,
#  'unrealistic,': 3,
#  'combat': 87,
#  'system': 212,
#  'unplayable': 25,
#  'convinced': 178,
#  'me': 681,
#  'knizia': 10,
#  'vastly': 17,
#  'overrated.': 41,
#  'exercise': 238,
#  'narcolepsy': 1,
#  'dreary': 8,
#  'deary': 1,
#  'dreary.': 1,
#  'losing': 55,
#  'at': 197,
#  'uno': 10,
#  'winning': 99,
#  'modern': 64,
#  'kind': 58,
#  'used': 41,
#  'bamboozled': 1,
#  'tom': 8,
#  'vasel': 10,
#  'his': 224,
#  'infomercial': 1,
#  'reviews.': 40,
#  '$11': 7,
#  'target,': 6,
#  'no,': 13,
#  'if': 67,
#  'they': 70,
#  'paid': 37,
#  '$10.': 21,
#  'because': 249,
#  'received': 11,
#  'it.': 4976,
#  'victim': 17,
#  'shameful': 1,
#  'aurora': 1,
#  'crowdfunding': 3,
#  'add': 137,
#  'rate': 320,
#  '1': 3010,
#  'without': 135,
#  'doubts': 30,
#  '=)': 170,
#  'dice': 55,
#  'fest.': 119,
#  'push': 80,
#  'your': 299,
#  'luck': 96,
#  'skills,': 18,
#  'tactic,': 11,
#  'jusr': 2,
#  'plain': 160,
#  'much': 207,
#  'downtime,': 123,
#  'rolling': 76,
#  'ass.': 28,
#  "can't": 33,
#  'stand': 265,
#  'finish': 358,
#  '2': 12685,
#  'turns.': 323,
#  'soul': 27,
#  'story': 76,
#  'reaction': 65,
#  'matrix.': 3,
#  'guess': 61,
#  'story-telling': 52,
#  'us': 56,
#  'nice': 25,
#  'graphical': 26,
#  'production,': 50,
#  'okay': 36,
#  'physical': 56,
#  'production.': 155,
#  'definition.': 4,
#  'league': 22,
#  'killer': 28,
#  'bunnies.': 6,
#  'horrible!': 14,
#  'plays': 38,
#  'you,': 100,
#  'despise': 31,
#  'why': 26,
#  'many': 160,
#  'fluxx': 12,
#  'expansions': 98,
#  'varieties?': 1,
#  'thought': 136,
#  'dull,': 60,
#  'aggravating': 10,
#  'long.': 516,
#  "i'd": 10,
#  'pay': 112,
#  'candyland.': 12,
#  'made.': 503,
#  'drawing': 108,
#  'playing': 169,
#  'cards.': 515,
#  'far': 104,
#  'has': 74,
#  'decisions.': 1197,
#  'math': 31,
#  'trade': 41,
#  'some': 66,
#  'end': 227,
#  '5': 4824,
#  'minutes,': 131,
#  'others': 222,
#  'here': 222,
#  'choices': 463,
#  'meaningless.': 21,
#  'soulless': 31,
#  'kingdom': 12,
#  'builder!': 18,
#  'filler.': 646,
#  'large': 179,
#  'group.': 1100,
#  'since': 157,
#  'zero': 40,
#  'strategy..': 8,
#  'game..': 189,
#  'activity.': 115,
#  'people': 272,
#  'sitting': 105,
#  'around': 644,
#  'table': 250,
#  'laughing': 93,
#  'about': 689,
#  'how': 84,
#  'funny': 37,
#  'was.': 125,
#  'idea': 430,
#  'published': 65,
#  'gives': 49,
#  'shivers...yup,': 1,
#  'would': 55,
#  'laundry': 7,
#  '"game".': 28,
#  'clean': 60,
#  'bathroom': 5,
#  '"game"....seriously,': 1,
#  'cards': 119,
#  'each': 120,
#  'face': 163,
#  'randomly': 74,
#  'determine': 199,
#  'winner': 121,
#  'instead.': 394,
#  'will': 57,
#  'faster.': 135,
#  'when': 163,
#  'fluxx,': 10,
#  'waste': 72,
#  'opportunity': 209,
#  'yes,': 17,
#  'saying': 202,
#  'ugh.': 9,
#  'original': 74,
#  'space.[color=#ffffff]a9z4mnax[/color]': 1,
#  'generous': 26,
#  'grade.': 25,
#  'randomness.': 254,
#  'definitive': 42,
#  '1.': 155,
#  'probably': 26,
#  'better': 51,
#  'do.': 904,
#  'objective:': 4,
#  'co-operate': 9,
#  'escape,': 4,
#  'shamelessly,': 1,
#  'as': 114,
#  'time': 453,
#  'possible.': 224,
#  'make': 479,
#  'stop!': 8,
#  'determined': 103,
#  'reshuffle': 5,
#  'deck...': 6,
#  'random?': 11,
#  'double': 46,
#  'entry': 68,
#  'top': 65,
#  '100,': 5,
#  'correction': 5,
#  'actual': 129,
#  'rating.': 328,
#  'overall': 43,
#  'changes': 73,
#  'between': 232,
#  'new': 86,
#  'minor.': 3,
#  'second': 60,
#  'edition': 31,
#  'love': 67,
#  '10': 2827,
#  '!.': 2,
#  'low': 40,
#  'dont': 68,
#  'through': 112,
#  'ages': 55,
#  'focus': 152,
#  'direct': 49,
#  'conflict.': 133,
#  'definitely': 18,
#  'number': 226,
#  'masterpiece!': 13,
#  'rulebook': 53,
#  'bit': 666,
#  'messy': 48,
#  'lot': 421,
#  'resources': 207,
#  'bgg.': 11,
#  'rated': 33,
#  'fake': 28,
#  'chinese': 12,
#  'copy': 121,
#  'ebay.': 11,
#  'rolled!': 1,
#  'anything': 71,
#  'serial': 12,
#  'killing': 102,
#  'gets': 134,
#  'marks': 35,
#  'hard': 74,
#  'pass.': 16,
#  'all': 53,
#  'passion': 20,
#  'universe.': 61,
#  'under': 124,
#  'circumstances': 27,
#  'awful': 82,
#  'experience.': 1280,
#  'punishes': 33,
#  'finish,': 25,
#  'no/minimal': 1,
#  'involved.': 736,
#  'well': 53,
#  'pissing': 9,
#  'into': 2761,
#  'wind': 54,
#  'assemble': 17,
#  'ugly': 33,
#  'jigsaw': 20,
#  'puzzle': 148,
#  'then': 129,
#  'sit': 51,
#  'things': 292,
#  'happen': 178,
#  'hit,': 39,
#  'disappointing': 42,
#  'time.': 1773,
#  'really,': 39,
#  'understand': 864,
#  "what's": 16,
#  'simply': 52,
#  'draws!': 4,
#  'goes': 108,
#  'first': 79,
#  'win': 322,
#  'or': 469,
#  'draw.': 150,
#  'buy': 50,
#  'it!': 187,
#  'save': 62,
#  'money!': 27,
#  'activity': 184,
#  'im': 25,
#  'sure': 266,
#  'players': 101,
#  'ideas.': 73,
#  'such': 66,
#  'seems': 37,
#  'awesome': 21,
#  'be.': 938,
#  'ugliest': 16,
#  'art': 119,
#  'produced,': 46,
#  'subject': 84,
#  'flimsiest': 1,
#  'interpretation.': 6,
#  'possible': 156,
#  'anyone': 71,
#  'actually': 103,
#  'likes': 550,
#  'game?': 334,
#  'maybe': 17,
#  'children': 162,
#  'understand,': 166,
#  'adult': 56,
#  'find': 287,
#  'enjoyment': 53,
#  'horrible': 67,
#  'mess': 141,
#  'surprises': 42,
#  'party': 54,
#  'games,': 299,
#  'although': 54,
#  'few': 266,
#  '(e.g.': 41,
#  'taboo': 12,
#  'pictionary).': 1,
#  'dixit': 12,
#  'left': 65,
#  'cold.': 63,
#  'pull': 222,
#  'strategically.': 28,
#  'big,': 15,
#  'crowded,': 11,
#  'warped': 18,
#  'board,': 76,
#  'slow,': 71,
#  'overated.': 6,
#  'pure': 28,
#  'war': 29,
#  'genre': 240,
#  'does': 103,
#  'hold': 156,
#  'appeal': 503,
#  'poor': 66,
#  'component': 40,
#  'seen.': 158,
#  'purchase': 115,
#  'rubbish.': 12,
#  'abstract': 86,
#  'luck,': 221,
#  'micro': 35,
#  'management.': 274,
#  'multiplayer,': 22,
#  'bring': 202,
#  'book.': 101,
#  'likey': 5,
#  'great,': 61,
#  'theme': 96,
#  'seemed': 52,
#  'elementary': 27,
#  'hlped': 1,
#  'foster': 4,
#  'opinion.': 641,
#  'us.': 151,
#  'enjoyable': 73,
#  'several': 63,
#  'years': 316,
#  '(and': 182,
#  'cooperative': 70,
#  'games).': 67,
#  'interesting': 41,
#  'combos..': 2,
#  'deal': 139,
#  'damage': 46,
#  'or..': 2,
#  '?': 189,
#  '2nd': 694,
#  '"enhanced"': 2,
#  'edition;': 15,
#  'cards,': 490,
#  'bagged': 26,
#  'tokens,': 47,
#  'divider': 5,
#  'tabs,': 1,
#  'foam': 42,
#  'stopper': 3,
#  'blocks': 75,
#  'slow': 74,
#  'uneven.': 10,
#  'essen!': 3,
#  'kickstarter!': 5,
#  'both': 67,
#  'losers': 17,
#  'please': 19,
#  'https://www.youtube.com/watch?v=dpcop1x2auu&index=30&list=plolrvtbmd6tllf0mk6nvy9vzt4m7gy-yg': 1,
#  'yeah': 16,
#  'hoping': 41,
#  'something': 148,
#  'less': 127,
#  'obvious': 174,
#  'interesting.': 249,
#  'co-op': 56,
#  'money.': 213,
#  'reason': 658,
#  'this,': 820,
#  "doesn't": 93,
#  'trick': 136,
#  'friends': 172,
#  'big': 29,
#  'fans.': 143,
#  'already': 118,
#  'friends.': 818,
#  'viking;),': 1,
#  'all...': 42,
#  'unbalanced': 74,
#  'progressively': 19,
#  'un-funny': 3,
#  'whatever': 56,
#  'willingness': 17,
#  'munchkin.': 12,
#  'boulder': 3,
#  'manure': 1,
#  'starts': 34,
#  'trundle': 1,
#  'down': 425,
#  'hill.': 9,
#  'said': 429,
#  'mille': 9,
#  'bornes,': 2,
#  'longer.': 191,
#  'adds': 29,
#  'nothing.': 43,
#  'mutant': 8,
#  'meeples': 52,
#  '(acrroding': 1,
#  'vasel)': 2,
#  'definition': 72,
#  'rely': 36,
#  'box?': 8,
#  'blecch.': 2,
#  'flipping': 40,
#  'timed': 41,
#  'solving.': 20,
#  '*hate*': 1,
#  'wanted': 189,
#  'multiplayer': 50,
#  'puzzles,': 30,
#  'pass': 147,
#  'couple': 667,
#  'sheets': 41,
#  'trig': 1,
#  'problems.': 108,
#  'equally': 44,
#  'hands': 70,
#  'jaw': 6,
#  'agape': 1,
#  'person': 639,
#  "who's": 58,
#  '"game"': 96,
#  'everything': 52,
#  'him': 143,
#  'her': 137,
#  'self.': 13,
#  'wheeee!!!': 1,
#  'mind': 281,
#  'blowing': 39,
#  'tedium.': 23,
#  'confusing': 84,
#  'fell': 51,
#  'asleep': 19,
#  'playing,': 295,
#  'still': 46,
#  'on.': 1016,
#  'woeful': 4,
#  'meaningful': 202,
#  'best': 39,
#  'times,': 890,
#  'terrible.': 78,
#  'group': 270,
#  'knows': 376,
#  'full': 50,
#  'same': 48,
#  'day.': 221,
#  'never.': 14,
#  'online': 107,
#  'made': 134,
#  'down.': 346,
#  'yourself': 271,
#  'eldritch.': 7,
#  'unplayably': 3,
#  'complicated,': 61,
#  'joke': 54,
#  'impossible': 86,
#  'give': 69,
#  'blegh.': 3,
#  'total': 27,
#  'dog': 33,
#  '3-4': 582,
#  'loathed': 6,
#  'until': 163,
#  'arkham': 11,
#  'horror.': 13,
#  'work,': 130,
#  'itself.': 290,
#  'bother!': 1,
#  'real': 178,
#  'sort': 77,
#  'malarkey': 1,
#  'go': 66,
#  'basically': 32,
#  'wasted': 51,
#  'this.': 876,
#  "haven't": 29,
#  'able': 298,
#  'story.': 157,
#  'boring,': 70,
#  'engaging': 114,
#  '2er': 11,
#  'components.': 618,
#  'travel': 67,
#  'spreadsheet': 17,
#  'carcassonne': 10,
#  'expansion': 77,
#  ';d': 4,
#  'carc': 11,
#  'add-on': 23,
#  'meeple': 35,
#  'feel': 660,
#  'ruins': 77,
#  'carcassonne.': 11,
#  'mod': 14,
#  'tiles': 270,
#  'cathars': 2,
#  'expansion,': 139,
#  'becomes': 91,
#  'useful': 40,
#  'tile-set': 1,
#  'fraction': 21,
#  'cost.': 39,
#  'ridiculously': 29,
#  'expensive': 47,
#  '30': 1011,
#  'wooden': 73,
#  'components...': 30,
#  'fan': 871,
#  'these': 119,
#  'crazy': 33,
#  'all.': 885,
#  'work': 321,
#  'create': 131,
#  'bad.': 397,
#  'luck.': 605,
#  'choice': 244,
#  'teaching': 141,
#  'kids': 60,
#  'let': 56,
#  'you...': 22,
#  'argh!': 7,
#  'truly': 39,
#  'mind-numbing.': 2,
#  'still,': 12,
#  'suppose': 109,
#  'name': 47,
#  'appropriate.': 17,
#  'terrible': 70,
#  'hated': 25,
#  'kid': 231,
#  'ranks': 18,
#  'below': 46,
#  'baseline': 8,
#  'bottom.': 13,
#  'father': 46,
#  'moan': 1,
#  'it&#039;s': 18,
#  '&#039;game&#039;,': 1,
#  'he': 51,
#  'realised': 26,
#  'mimic': 8,
#  'life?': 14,
#  'don&#039;t': 33,
#  '&quot;escape&quot;': 1,
#  'version': 411,
#  'candyland': 9,
#  'remember.': 70,
#  'do?': 14,
#  'pathetic.': 5,
#  'milton': 8,
#  "bradley's": 2,
#  '(the': 63,
#  'checkered': 2,
#  'life)': 2,
#  'offered': 43,
#  'decision': 457,
#  'making': 146,
#  '(even': 121,
#  'usually': 68,
#  'obvious)': 2,
#  'lamest': 3,
#  'lame': 40,
#  'slayed': 1,
#  'lewis': 6,
#  'clark': 3,
#  'discoveries.': 1,
#  'our': 42,
#  '6': 3436,
#  'friends:': 6,
#  'boring.i': 1,
#  'ask': 249,
#  'myself': 486,
#  'question': 92,
#  'whether': 119,
#  'editor': 7,
#  'tested': 27,
#  'all!': 92,
#  'again!!!': 11,
#  "didn't": 52,
#  'unappealing': 13,
#  'interest': 258,
#  'either.': 506,
#  'prefer': 75,
#  'try': 148,
#  'king': 18,
#  'tokyo/new': 2,
#  'york': 9,
#  'bang!': 11,
#  'funniest': 11,
#  'thing': 1030,
#  'yell': 38,
#  'during': 259,
#  'sex.': 2,
#  'recommend': 103,
#  'simplicity': 113,
#  'randomness': 123,
#  'worst.': 33,
#  'chance.': 249,
#  'cool,': 71,
#  'though.': 5391,
#  'example': 197,
#  'passed': 24,
#  'family': 127,
#  'kid.': 451,
#  'dull': 167,
#  'activity,': 64,
#  'club': 36,
#  'copy.': 187,
#  'gahhhhhh.': 1,
#  'yahtzee?': 8,
#  'trains': 15,
#  'stations': 38,
#  'elder': 15,
#  'signs': 18,
#  'tokyo.': 10,
#  'puh-lease.': 2,
#  'know': 1381,
#  'yahtzee': 10,
#  'popular': 113,
#  'dice,': 95,
#  'mark': 30,
#  'score.': 269,
#  'favourite': 271,
#  'time,': 1089,
#  'say.': 295,
#  'once,': 684,
#  'minimal': 28,
#  'enthusiasm.': 8,
#  'missing?': 8,
#  'math.': 78,
#  'dentist....': 1,
#  'enjoyed': 69,
#  'detest': 12,
#  'hot': 57,
#  'pokers': 2,
#  'shoved': 8,
#  'pants': 19,
#  'hear': 124,
#  '"yathzee!"': 1,
#  'technically': 13,
#  'own': 92,
#  'enough': 268,
#  'play,': 1064,
#  'slightly': 68,
#  'entertaining': 89,
#  'watching': 129,
#  'paint': 58,
#  'dry.': 133,
#  'feeling': 679,
#  'thinking': 117,
#  'seeks': 3,
#  'evoke;': 1,
#  'beyond': 72,
#  'that,': 112,
#  'mechanics': 91,
#  'were': 1366,
#  'utterly': 19,
#  'meaningless': 36,
#  'teams': 61,
#  'others.': 574,
#  'unbalanced.': 103,
#  'ffg': 11,
#  'bluff...': 3,
#  'someone': 166,
#  'claimed': 8,
#  'solved': 50,
#  'problems': 179,
#  'classic': 38,
#  'risk.': 15,
#  "doesn't.": 46,
#  ...}

# %%
# %%time
new_data = {k: v for k, v in all_dict.items() if v > 5}
# Out:
# CPU times: user 19.2 ms, sys: 355 µs, total: 19.5 ms
# Wall time: 19.4 ms

# %%
# %%time
sortedList=sorted(new_data.values())
sorted_dict = dict()
for sortedKey in sortedList:
    for key, value in new_data.items():
        if value==sortedKey:
            sorted_dict[key]=value
# Out:
# CPU times: user 1min 37s, sys: 650 ms, total: 1min 37s
# Wall time: 1min 39s

# %%
# %%time
dict_list = []
for key, value in sorted_dict.items():
    temp = [key,value]
    dict_list.append(temp)
# Out:
# CPU times: user 91.8 ms, sys: 267 ms, total: 359 ms
# Wall time: 373 ms

# %%
dict_list[-10:]
# Out:
# [['5', 4824],
#  ['it.', 4976],
#  ['though.', 5391],
#  ['3', 5426],
#  ['me.', 5597],
#  ['than', 6287],
#  ['4', 6590],
#  ['2', 12685],
#  ['-', 17661],
#  ['', 179603]]

# %%
report = []
error = []

# %%
testing_df = df.loc[df.comment.apply(lambda x: len(x.split(' ')))<30].copy()

# %%
def make_it_lower(comment):
    new_comment = []
    for x in comment.split(' '):
        new_comment.append(x.lower())
    return ' '.join(new_comment)

# %%
# %%time
testing_df['lower_comment'] = testing_df.comment.apply(lambda x: make_it_lower(x))
# Out:
# CPU times: user 3.03 s, sys: 77.1 ms, total: 3.11 s
# Wall time: 3.16 s

# %%
# %%time
testing_df.drop(columns=['comment'], inplace=True)
testing_df.rename(columns={'lower_comment':'comment'}, inplace=True)
# Out:
# CPU times: user 113 ms, sys: 21.6 ms, total: 134 ms
# Wall time: 267 ms

# %%
testing_df.head()
# Out:
#    commenter  gameID  rating  \
# 1      86674   24068     7.0
# 5       2227    5405    10.0
# 6     127164    5405    10.0
# 7      99693    5405    10.0
# 8     108476    5405    10.0
#
#                                              comment
# 1  a neat social deduction game with multiple tea...
# 5  this is really part of the base set, and i wou...
# 6                               we love the builder!
# 7  every carc original game gets played with this...
# 8  must have! should be included in the base game!!!

# %%
def word_count(comment):
    if word[0] in comment.split(' '):
        if word[0] in number:
            number[word[0]] += comment.split(' ').count(word[0])
        else:
            number[word[0]] = comment.split(' ').count(word[0])

# %%
def word_count_list(comment):
    if word in comment.split(' '):
        if word in number:
            number[word] += comment.split(' ').count(word)
        else:
            number[word] = comment.split(' ').count(word)

# %%
# %%time
for word in dict_list[-5:]:
    try:
        to_append = []
        for y in range(1,11):
            number = dict()
            testing_df.loc[testing_df.rating == y].comment.apply(word_count)
            divisor = testing_df.loc[df.rating == y].comment.count()
            to_append.append([y, number[word[0]], divisor])
        report.append([word[0], to_append])
    except KeyError:
        error.append(word[0])
        continue
# Out:
# CPU times: user 7.49 s, sys: 246 ms, total: 7.74 s
# Wall time: 7.87 s

# %%
error
# Out:
# []

# %%
report
# Out:
# [['than',
#   [[1, 100, 2219],
#    [2, 208, 4575],
#    [3, 322, 8644],
#    [4, 716, 15691],
#    [5, 1288, 29252],
#    [6, 2895, 61498],
#    [7, 5190, 113929],
#    [8, 5237, 126791],
#    [9, 2533, 71451],
#    [10, 992, 36081]]],
#  ['4',
#   [[1, 14, 2219],
#    [2, 30, 4575],
#    [3, 53, 8644],
#    [4, 179, 15691],
#    [5, 318, 29252],
#    [6, 708, 61498],
#    [7, 1627, 113929],
#    [8, 2024, 126791],
#    [9, 1125, 71451],
#    [10, 512, 36081]]],
#  ['2',
#   [[1, 21, 2219],
#    [2, 74, 4575],
#    [3, 113, 8644],
#    [4, 227, 15691],
#    [5, 444, 29252],
#    [6, 1264, 61498],
#    [7, 2956, 113929],
#    [8, 4164, 126791],
#    [9, 2336, 71451],
#    [10, 1086, 36081]]],
#  ['-',
#   [[1, 69, 2219],
#    [2, 117, 4575],
#    [3, 270, 8644],
#    [4, 536, 15691],
#    [5, 955, 29252],
#    [6, 2132, 61498],
#    [7, 4206, 113929],
#    [8, 5175, 126791],
#    [9, 2874, 71451],
#    [10, 1327, 36081]]],
#  ['',
#   [[1, 788, 2219],
#    [2, 1604, 4575],
#    [3, 3076, 8644],
#    [4, 5621, 15691],
#    [5, 10713, 29252],
#    [6, 22578, 61498],
#    [7, 42829, 113929],
#    [8, 49759, 126791],
#    [9, 28586, 71451],
#    [10, 14049, 36081]]]]

# %%
len(report)
# Out:
# 5

# %%
data = report

# %%
for word in data:
    print(word[0])
# Out:
# than
# 4
# 2
# -

# %%
useless = []
usefull = []

# %%
for word in data:
#     print(word[0])
    percent = []
    for reports in word[1]:
#         print(reports[1]/reports[2])
        percent.append(reports[1]/reports[2])
    x  = np.array(percent)
    print("for {} mean {} and the std {} mean/std {}".format(word[0], np.sum(x)/10, np.std(x), (np.sum(x)/10)/(np.std(x))))
# Out:
# for than mean 0.041432167499335454 and the std 0.005918051102212102 mean/std 7.000981705590303
# for 4 mean 0.011296883270108 and the std 0.003648284436465842 mean/std 3.0964919174590158
# for 2 mean 0.021049020230582725 and the std 0.008247269940054008 mean/std 2.55224096986995
# for - mean 0.03441139002299698 and the std 0.004348569169686267 mean/std 7.913267256475452
# for  mean 0.37109942606717106 and the std 0.01663125679488023 mean/std 22.313372383343292
# for bad mean 0.014709041412874518 and the std 0.008069236581839398 mean/std 1.8228541527681374
# for board mean 0.015128264492698829 and the std 0.004874645106477771 mean/std 3.103459669832236
# for boring mean 0.01926828840302357 and the std 0.018078816387685465 mean/std 1.065793688581755
# for hate mean 0.017280076078712448 and the std 0.024578997320901956 mean/std 0.7030423516917628
# for never mean 0.02417499771984185 and the std 0.01178898188359165 mean/std 2.0506433853706674
# for broken mean 0.0026346078533669307 and the std 0.0028507080726657527 mean/std 0.9241941953401274
# for worst mean 0.00612311813105155 and the std 0.010191250074678712 mean/std 0.6008211049854536
# for long mean 0.02459238162574665 and the std 0.00905745401047496 mean/std 2.7151539049831794

# %%
for word in data:
    print(word[0])
    percent = []
    for reports in word[1]:
        print(reports[1]/reports[2])
        percent.append(reports[1]/reports[2])
    x  = np.array(percent)
#     print("for {} the average is {} and the standard deviation is {}".format(word[0], np.sum(x)/10, np.std(x)))
# Out:
# than
# 0.04506534474988734
# 0.04546448087431694
# 0.037251272559000466
# 0.04563125358485756
# 0.0440311773553945
# 0.04707470161631273
# 0.04555468756857341
# 0.0413041935153126
# 0.03545086842731383
# 0.02749369474238519
# 4
# 0.006309148264984227
# 0.006557377049180328
# 0.006131420638593244
# 0.01140781339621439
# 0.010871051552030631
# 0.011512569514455754
# 0.0142808240219786
# 0.01596327815065738
# 0.015745056052399547
# 0.014190294060585903
# 2
# 0.00946372239747634
# 0.016174863387978144
# 0.013072651550208238
# 0.01446689184883054
# 0.015178449336797484
# 0.020553513935412535
# 0.025945983902254912
# 0.03284144773682675
# 0.032693734167471414
# 0.030098944042570883
# -
# 0.031095087877422264
# 0.025573770491803278
# 0.03123553910226747
# 0.034159709387547005
# 0.03264734035279639
# 0.034667794074604054
# 0.03691772946308666
# 0.04081519981702171
# 0.040223369861863374
# 0.03677835980155761
#
# 0.3551149166291122
# 0.35060109289617486
# 0.35585377140212865
# 0.3582308329615703
# 0.36623136879529605
# 0.3671338905330255
# 0.3759271124998903
# 0.3924489908589726
# 0.4000783753901275
# 0.38937390870541283
# bad
# 0.024785939612438034
# 0.023825136612021857
# 0.022327626099028226
# 0.018991778726658595
# 0.01883631888417886
# 0.016683469381118084
# 0.00941814638941797
# 0.005173868807722946
# 0.0036668486095366055
# 0.003381281006623985
# board
# 0.018476791347453808
# 0.011584699453551913
# 0.013188338732068487
# 0.009878274169906316
# 0.012204293723506085
# 0.011691437119906339
# 0.013929728164031985
# 0.015355979525360632
# 0.01736854627646919
# 0.027604556414733517
# boring
# 0.04821991888237945
# 0.04437158469945355
# 0.03771402128644146
# 0.02918870690204576
# 0.018015862163270887
# 0.008650687827246414
# 0.0030106469818922312
# 0.0014906420802738365
# 0.0011616352465325887
# 0.0008591779606995372
# hate
# 0.08111762054979721
# 0.04371584699453552
# 0.018741323461360482
# 0.010834236186348862
# 0.005811568439764802
# 0.0037074376402484632
# 0.002624441538150954
# 0.002334550559582305
# 0.0020013715693272312
# 0.0019123638480086473
# never
# 0.03875619648490311
# 0.049398907103825135
# 0.03146691346598797
# 0.02561978204066025
# 0.019827704088609326
# 0.01585417411948356
# 0.011647605087378981
# 0.011893588661655796
# 0.014863332913465171
# 0.02242177323244921
# broken
# 0.010365029292474088
# 0.005245901639344262
# 0.001966682091624248
# 0.0018481932317889235
# 0.0017092848352249419
# 0.0012032911639402908
# 0.0009567362129045282
# 0.0011278403041225325
# 0.0010916572196330353
# 0.0008314625426124553
# worst
# 0.034249662009914375
# 0.013989071038251366
# 0.005090236001850995
# 0.0038238480657701865
# 0.0016750991385204432
# 0.0009268594100621158
# 0.0005880855620605816
# 0.0003312537956164081
# 0.00027991210759821414
# 0.00027715418087081843
# long
# 0.021631365479945923
# 0.036721311475409836
# 0.03771402128644146
# 0.03282136256452744
# 0.03001504170654998
# 0.02663501252073238
# 0.01945071053024252
# 0.015261335583755945
# 0.013589732823893298
# 0.012083922285967684

# %%
# %%time
for word in dict_list[-5:]:
    try:
        to_append = []
        for y in range(1,11):
            number = dict()
            testing_df.loc[testing_df.rating == y].comment.apply(word_count)
            divisor = testing_df.loc[df.rating == y].comment.count()
            to_append.append([y, number[word[0]], divisor])
        report.append([word[0], to_append])
    except KeyError:
        error.append(word[0])
        continue

# %%
bad_words = ['bad', 'board', 'boring', 'hate', 'never', 'broken', 'worst', 'long']

# %%
# %%time
for word in bad_words:
    to_append = []
    for y in range(1,11):
        number = dict()
        testing_df.loc[testing_df.rating == y].comment.apply(word_count_list)
        divisor = testing_df.loc[df.rating == y].comment.count()
        to_append.append([y, number[word], divisor])
    report.append([word, to_append])
# Out:
# CPU times: user 11.2 s, sys: 509 ms, total: 11.7 s
# Wall time: 12.1 s
