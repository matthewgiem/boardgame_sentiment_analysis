# %%
from decimal import Decimal
import pandas as pd
import math

# %%
num = 0.0014

# %%
'%.2E' % Decimal(num)
# Out:
# '1.40E-03'

# %%
type(num)
# Out:
# float

# %%
str('%.2E' % Decimal(num)).split()
# Out:
# ['1.40E-03']

# %%
num
# Out:
# 1.4e-05

# %%
int(str('%.2E' % Decimal(num)).split('E')[1][1:3])
# Out:
# 3

# %%
num*10**(int(str(num).split('e')[1][1:3]))
# Out:
# 1.4

# %%
def find_higest_power(series):
    higest = 0
    for x in series:
        if higest < int(str('%.2E' % Decimal(num)).split('E')[1][1:3]):
            higest = int(str('%.2E' % Decimal(num)).split('E')[1][1:3])
    return higest

# %%
df = pd.read_csv('data.csv')

# %%
df.loc[df.word == 'hate']
# Out:
#        Unnamed: 0  word  average_std  percent_average  percent_std  rating  \
# 38577         660  hate      0.69701         0.018206      0.02612     NaN
# 38578         661  hate          NaN              NaN          NaN     1.0
# 38579         662  hate          NaN              NaN          NaN     2.0
# 38580         663  hate          NaN              NaN          NaN     3.0
# 38581         664  hate          NaN              NaN          NaN     4.0
# 38582         665  hate          NaN              NaN          NaN     5.0
# 38583         666  hate          NaN              NaN          NaN     6.0
# 38584         667  hate          NaN              NaN          NaN     7.0
# 38585         668  hate          NaN              NaN          NaN     8.0
# 38586         669  hate          NaN              NaN          NaN     9.0
# 38587         670  hate          NaN              NaN          NaN    10.0
#
#        word_count   divisor   percent      time
# 38577         NaN       NaN       NaN  2.043586
# 38578       189.0    2177.0  0.086817       NaN
# 38579       203.0    4527.0  0.044842       NaN
# 38580       168.0    8567.0  0.019610       NaN
# 38581       178.0   15584.0  0.011422       NaN
# 38582       174.0   29081.0  0.005983       NaN
# 38583       241.0   61091.0  0.003945       NaN
# 38584       319.0  113108.0  0.002820       NaN
# 38585       303.0  125466.0  0.002415       NaN
# 38586       151.0   70468.0  0.002143       NaN
# 38587        73.0   35426.0  0.002061       NaN

# %%
def write_statistics(series, df):
    numbers = []
    total = 0
    for x in series:
        if not math.isnan(x):
            numbers.append(x)
            totat += x
    normilization_divisor = total/100
    df.loc[df.word == series.name].loc[df.type == 1]['normilization_divisor'] = normilization_divisor

# %%
df.drop(columns=['Unnamed: 0'], inplace=True)

# %%
df.type = 0

# %%
df['type'] = 0

# %%
df.loc[df.time>0]['type'] = 1
# Out:
# /usr/local/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df
# Out:
#                 word  average_std  percent_average  percent_std  rating  \
# 0             caylus     4.023446         0.001030     0.000256     NaN
# 1             caylus          NaN              NaN          NaN     1.0
# 2             caylus          NaN              NaN          NaN     2.0
# 3             caylus          NaN              NaN          NaN     3.0
# 4             caylus          NaN              NaN          NaN     4.0
# 5             caylus          NaN              NaN          NaN     5.0
# 6             caylus          NaN              NaN          NaN     6.0
# 7             caylus          NaN              NaN          NaN     7.0
# 8             caylus          NaN              NaN          NaN     8.0
# 9             caylus          NaN              NaN          NaN     9.0
# 10            caylus          NaN              NaN          NaN    10.0
# 11          ultimate     1.015468         0.000979     0.000964     NaN
# 12          ultimate          NaN              NaN          NaN     1.0
# 13          ultimate          NaN              NaN          NaN     2.0
# 14          ultimate          NaN              NaN          NaN     3.0
# 15          ultimate          NaN              NaN          NaN     4.0
# 16          ultimate          NaN              NaN          NaN     5.0
# 17          ultimate          NaN              NaN          NaN     6.0
# 18          ultimate          NaN              NaN          NaN     7.0
# 19          ultimate          NaN              NaN          NaN     8.0
# 20          ultimate          NaN              NaN          NaN     9.0
# 21          ultimate          NaN              NaN          NaN    10.0
# 22           various     2.360543         0.000853     0.000362     NaN
# 23           various          NaN              NaN          NaN     1.0
# 24           various          NaN              NaN          NaN     2.0
# 25           various          NaN              NaN          NaN     3.0
# 26           various          NaN              NaN          NaN     4.0
# 27           various          NaN              NaN          NaN     5.0
# 28           various          NaN              NaN          NaN     6.0
# 29           various          NaN              NaN          NaN     7.0
# ...              ...          ...              ...          ...     ...
# 51087       diseases          NaN              NaN          NaN     3.0
# 51088       diseases          NaN              NaN          NaN     4.0
# 51089       diseases          NaN              NaN          NaN     5.0
# 51090       diseases          NaN              NaN          NaN     6.0
# 51091       diseases          NaN              NaN          NaN     7.0
# 51092       diseases          NaN              NaN          NaN     8.0
# 51093       diseases          NaN              NaN          NaN     9.0
# 51094       diseases          NaN              NaN          NaN    10.0
# 51095  card-drafting     1.121885         0.000137     0.000122     NaN
# 51096  card-drafting          NaN              NaN          NaN     1.0
# 51097  card-drafting          NaN              NaN          NaN     2.0
# 51098  card-drafting          NaN              NaN          NaN     3.0
# 51099  card-drafting          NaN              NaN          NaN     4.0
# 51100  card-drafting          NaN              NaN          NaN     5.0
# 51101  card-drafting          NaN              NaN          NaN     6.0
# 51102  card-drafting          NaN              NaN          NaN     7.0
# 51103  card-drafting          NaN              NaN          NaN     8.0
# 51104  card-drafting          NaN              NaN          NaN     9.0
# 51105  card-drafting          NaN              NaN          NaN    10.0
# 51106         bagged     0.984727         0.000147     0.000149     NaN
# 51107         bagged          NaN              NaN          NaN     1.0
# 51108         bagged          NaN              NaN          NaN     2.0
# 51109         bagged          NaN              NaN          NaN     3.0
# 51110         bagged          NaN              NaN          NaN     4.0
# 51111         bagged          NaN              NaN          NaN     5.0
# 51112         bagged          NaN              NaN          NaN     6.0
# 51113         bagged          NaN              NaN          NaN     7.0
# 51114         bagged          NaN              NaN          NaN     8.0
# 51115         bagged          NaN              NaN          NaN     9.0
# 51116         bagged          NaN              NaN          NaN    10.0
#
#        word_count   divisor   percent      time  type
# 0             NaN       NaN       NaN  2.294487     0
# 1             1.0    2177.0  0.000459       NaN     0
# 2             5.0    4527.0  0.001104       NaN     0
# 3             7.0    8567.0  0.000817       NaN     0
# 4            13.0   15584.0  0.000834       NaN     0
# 5            36.0   29081.0  0.001238       NaN     0
# 6            73.0   61091.0  0.001195       NaN     0
# 7           119.0  113108.0  0.001052       NaN     0
# 8           146.0  125466.0  0.001164       NaN     0
# 9           100.0   70468.0  0.001419       NaN     0
# 10           36.0   35426.0  0.001016       NaN     0
# 11            NaN       NaN       NaN  2.079468     0
# 12            1.0    2177.0  0.000459       NaN     0
# 13            1.0    4527.0  0.000221       NaN     0
# 14            5.0    8567.0  0.000584       NaN     0
# 15            5.0   15584.0  0.000321       NaN     0
# 16           11.0   29081.0  0.000378       NaN     0
# 17           41.0   61091.0  0.000671       NaN     0
# 18           91.0  113108.0  0.000805       NaN     0
# 19          140.0  125466.0  0.001116       NaN     0
# 20          114.0   70468.0  0.001618       NaN     0
# 21          128.0   35426.0  0.003613       NaN     0
# 22            NaN       NaN       NaN  2.031647     0
# 23            1.0    2177.0  0.000459       NaN     0
# 24            2.0    4527.0  0.000442       NaN     0
# 25            4.0    8567.0  0.000467       NaN     0
# 26            8.0   15584.0  0.000513       NaN     0
# 27           21.0   29081.0  0.000722       NaN     0
# 28           59.0   61091.0  0.000966       NaN     0
# 29          137.0  113108.0  0.001211       NaN     0
# ...           ...       ...       ...       ...   ...
# 51087         0.0    8567.0  0.000000       NaN     0
# 51088         0.0   15584.0  0.000000       NaN     0
# 51089         0.0   29081.0  0.000000       NaN     0
# 51090         2.0   61091.0  0.000033       NaN     0
# 51091        12.0  113108.0  0.000106       NaN     0
# 51092        28.0  125466.0  0.000223       NaN     0
# 51093        11.0   70468.0  0.000156       NaN     0
# 51094        11.0   35426.0  0.000311       NaN     0
# 51095         NaN       NaN       NaN  2.006215     0
# 51096         1.0    2177.0  0.000459       NaN     0
# 51097         0.0    4527.0  0.000000       NaN     0
# 51098         0.0    8567.0  0.000000       NaN     0
# 51099         2.0   15584.0  0.000128       NaN     0
# 51100         2.0   29081.0  0.000069       NaN     0
# 51101         9.0   61091.0  0.000147       NaN     0
# 51102        15.0  113108.0  0.000133       NaN     0
# 51103        22.0  125466.0  0.000175       NaN     0
# 51104        10.0   70468.0  0.000142       NaN     0
# 51105         4.0   35426.0  0.000113       NaN     0
# 51106         NaN       NaN       NaN  2.028656     0
# 51107         1.0    2177.0  0.000459       NaN     0
# 51108         0.0    4527.0  0.000000       NaN     0
# 51109         0.0    8567.0  0.000000       NaN     0
# 51110         1.0   15584.0  0.000064       NaN     0
# 51111        10.0   29081.0  0.000344       NaN     0
# 51112        15.0   61091.0  0.000246       NaN     0
# 51113        16.0  113108.0  0.000141       NaN     0
# 51114        16.0  125466.0  0.000128       NaN     0
# 51115         6.0   70468.0  0.000085       NaN     0
# 51116         0.0   35426.0  0.000000       NaN     0
#
# [51117 rows x 10 columns]
