# %%
import pandas as pd
import math
import numpy as np
import matplotlib.pyplot as plt

# %%
words = pd.read_csv('words.csv')
words.drop(columns=['Unnamed: 0'], inplace=True)

# %%
words.loc[words.total_word_count>100].head()
# Out:
#            word  average/std  percent_average  percent_std  rating  \
# 700     damaged     5.813332         0.000386     0.000066     NaN
# 701  overpriced     1.858004         0.000558     0.000300     NaN
# 702   greatness     1.359791         0.000309     0.000227     NaN
# 703     tightly     2.747200         0.000351     0.000128     NaN
# 704    mentally     1.070365         0.000533     0.000498     NaN
#
#      word_count  divisor  percent  type  normilization_divisor  \
# 700         NaN      NaN      NaN     1               0.003858
# 701         NaN      NaN      NaN     1               0.005579
# 702         NaN      NaN      NaN     1               0.003087
# 703         NaN      NaN      NaN     1               0.003510
# 704         NaN      NaN      NaN     1               0.005329
#
#      normilized_percent      mean  median  mode  zeros  total_word_count  \
# 700                 0.0  5.310511       5     1      0             327.0
# ...

# %%
words[['word', 'average/std', 'percent_average', 'percent_std', '']]
