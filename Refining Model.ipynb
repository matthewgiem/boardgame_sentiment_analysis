# %%
import pandas as pd
import math
import numpy as np
import matplotlib.pyplot as plt

# %%
words = pd.read_csv('words.csv')
words.drop(columns=['Unnamed: 0'], inplace=True)

# %%
words
# Out:
#                      word  average/std  percent_average  percent_std  rating  \
# 0                 rockets     1.644846         0.000045     0.000027     NaN
# 1                gangster     1.043339         0.000040     0.000038     NaN
# 2                subjects     1.636259         0.000069     0.000042     NaN
# 3             collaborate     1.153882         0.000075     0.000065     NaN
# 4                    gasp     1.209620         0.000042     0.000035     NaN
# 5                       ●     0.798841         0.000034     0.000043     NaN
# 6                     yer     1.268789         0.000084     0.000066     NaN
# 7           area-majority     1.568648         0.000053     0.000034     NaN
# 8                 looming     1.686925         0.000046     0.000027     NaN
# 9                   warts     1.600973         0.000041     0.000026     NaN
# 10                 tragic     0.678949         0.000160     0.000235     NaN
# ...
